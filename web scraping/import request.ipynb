# %% [markdown]
# ##### <b> requests</b> is a popular <span style="color:blue"> Python library used to send HTTP requests easily</span> It allows you to communicate with web servers.For example, to get data from an API or submit data to a website.

# %%
import requests

# %%
response=requests.get("https://api.github.com")
print(response.status_code)
print(response.json())
# Out:
# 200
# ...
